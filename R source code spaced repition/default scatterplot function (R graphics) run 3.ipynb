# %% [markdown]
# Pimps Lamented But Crisp Orphans Stroked Homer Nicely.
#
# Panting Ladies Became Cops
#
# Obese Simba Handled Nudists.
#
# [Mnemonic generator](https://www.mnemonicgenerator.com/)

# %%
plot(x = 1:10, y = (1:10)**2, type = "b")
# Out:
# plot without title

# %%
plot(x = 1:10, y = (1:10)**2, type = "l")
# Out:
# plot without title

# %%
plot(x = 1:10, y = (1:10)**2, type = "s")
# Out:
# plot without title

# %%
plot(x = 1:10, y = (1:10)**2, type = "S")
# Out:
# plot without title
