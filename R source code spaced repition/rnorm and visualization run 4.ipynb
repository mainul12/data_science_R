# %%
library(ggplot2)
# Out:
# Warning message:
# "package 'ggplot2' was built under R version 4.0.5"

# %%
data <- rnorm(1000, 10, 3)

# %%
hist(data)
# Out:
# Plot with title "Histogram of data"

# %%
df <- data.frame(data)

# %%
head(df)
# Out:
#   data
# 1  6.886209
# 2  6.766445
# 3 12.586089
# 4 13.998768
# 5  8.797271
# 6 12.639779

# %%
ggplot(df, aes(data)) + 
    geom_histogram(bins=50, color="black", fill="orange")
# Out:
# plot without title
