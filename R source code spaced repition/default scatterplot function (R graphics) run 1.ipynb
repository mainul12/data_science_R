# %% [markdown]
# ## [The default scatterplot function](https://stat.ethz.ch/R-manual/R-devel/library/graphics/html/plot.default.html)

# %%
df <- data.frame(A = 1:10, B = (1:10)**2)

# %%
plot(df, type = "p")
mtext("Default type p", line = -3)
# Out:
# plot without title

# %%
plot(df, type = "l")
mtext("type = l", line = -4)
# Out:
# plot without title

# %%
plot(df, type = "b")
# Out:
# plot without title

# %%
plot(df, type = "c")
# Out:
# plot without title

# %%
plot(df, type = "o")
# Out:
# plot without title

# %%
plot(df, type = "s")
# Out:
# plot without title

# %%
plot(df, type = "S")
# Out:
# plot without title

# %%
plot(df, type = "h")
# Out:
# plot without title

# %%
plot(df, type = "n")
# Out:
# plot without title
