# %%
plot(1:10, (1:10)**3, type = "p", col = "red")
# Out:
# plot without title

# %%
plot(1:10, (1:10)**3, type = "l")
# Out:
# plot without title

# %%
plot(1:10, (1:10)**3, type = "b")
# Out:
# plot without title

# %%
plot(1:10, (1:10)**3, type = "c")
# Out:
# plot without title

# %%
plot(1:10, (1:10)**3, type = "o")
# Out:
# plot without title

# %%
plot(1:10, (1:10)**3, type = "s")
# Out:
# plot without title

# %%
plot(1:10, (1:10)**3, type = "S")
# Out:
# plot without title

# %%
plot(1:10, (1:10)**3, type = "h")
# Out:
# plot without title

# %%
plot(1:10, (1:10)**3, type = "n")
# Out:
# plot without title
