# %%
plot(1:10, -(1:10)**2, type = "p")
# Out:
# plot without title

# %%
plot(1:10, -(1:10)**2, type = "l")
# Out:
# plot without title

# %%
plot(1:10, -(1:10)**2, type = "b")
# Out:
# plot without title

# %%
plot(1:10, -(1:10)**2, type = "c")
# Out:
# plot without title

# %%
plot(1:10, -(1:10)**2, type = "o")
# Out:
# plot without title

# %%
plot(1:10, -(1:10)**2, type = "s")
# Out:
# plot without title

# %%
plot(1:10, -(1:10)**2, type = "S")
# Out:
# plot without title

# %%
plot(1:10, -(1:10)**2, type = "h")
# Out:
# plot without title

# %%
plot(1:10, -(1:10)**2, type = "n")
# Out:
# plot without title
