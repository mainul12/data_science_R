# %%
library(tidyverse)
# Out:
# -- Attaching packages ------------------------------------------------------------------------------- tidyverse 1.3.1 --
#
# v ggplot2 3.3.4     v purrr   0.3.4
# v tibble  3.1.1     v dplyr   1.0.6
# v tidyr   1.1.3     v stringr 1.4.0
# v readr   1.4.0     v forcats 0.5.1
#
# -- Conflicts ---------------------------------------------------------------------------------- tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()

# %%
data <- read_csv("https://raw.githubusercontent.com/nytimes/covid-19-data/master/prisons/facilities.csv")
# Out:
# -- Column specification ------------------------------------------------------------------------------------------------
# cols(
#   nyt_id = col_character(),
#   facility_name = col_character(),
#   facility_type = col_character(),
#   facility_city = col_character(),
#   facility_county = col_character(),
#   facility_county_fips = col_character(),
#   facility_state = col_character(),
#   facility_lng = col_double(),
#   facility_lat = col_double(),
#   latest_inmate_population = col_double(),
#   max_inmate_population_2020 = col_double(),
#   total_inmate_cases = col_double(),
#   total_inmate_deaths = col_double(),
#   total_officer_cases = col_double(),
#   total_officer_deaths = col_double(),
#   note = col_character()
# )

# %%
dim(data)
# Out:
# [1] 2639   16

# %%
head(data)
# Out:
#   nyt_id
# 1 F3EFE858
# 2 5B910220
# 3 02FB1675
# 4 6378F6C4
# 5 EAABF900
# 6 D19A2461
#   facility_name
# 1 Alex City Work Release prison
# 2 Alabama Therapeutic Education Facility prison
# 3 Bibb Correctional Facility
# 4 Birmingham Women's Community Based Facility and Community Work Center
# 5 Bullock Correctional Facility
# 6 Camden prison
#   facility_type               facility_city facility_county
# 1 Low-security work release   Alex City     Coosa
# 2 State rehabilitation center Columbiana    Shelby
# 3 State prison                Brent         Bibb
# 4 State prison                Birmingham    Jefferson
# 5 State prison                Bessemer      Bullock
# 6 State prison                Camden        Wilcox
#   facility_county_fips facility_state facility_lng facility_lat
# 1 01037                Alabama        -86.00901    32.90451
# 2 01117                Alabama        -86.62407    33.18075
# 3 01007                Alabama        -87.16278    32.92075
# ...

# %%
data %>%
    arrange(desc(total_inmate_deaths)) %>%
    select(facility_state, total_inmate_deaths)
# Out:
#      facility_state total_inmate_deaths
# 1    Florida        45
# 2    Ohio           35
# 3    NA             31
# 4    North Carolina 30
# 5    Nevada         29
# 6    California     28
# 7    Kentucky       28
# 8    California     27
# 9    Florida        26
# 10   Michigan       24
# 11   Arkansas       22
# 12   Texas          21
# 13   Texas          19
# 14   Texas          19
# 15   Virginia       19
# 16   California     18
# 17   California     18
# 18   Louisiana      18
# 19   Missouri       18
# 20   Nevada         17
# 21   Alabama        16
# 22   Pennsylvania   16
# 23   Florida        15
# 24   Texas          15
# 25   Alabama        14
# 26   California     14
# 27   New Jersey     14
# 28   Ohio           14
# 29   Ohio           14
# 30   Pennsylvania   14
# ...  ...            ...
# 2610 Pennsylvania   0
# 2611 Washington     0
# 2612 Virginia       0
# 2613 Oregon         0
# 2614 North Carolina 0
# 2615 Missouri       0
# 2616 Ohio           0
# ...

# %%
data %>%
    filter(facility_state == "Florida")
# Out:
#     nyt_id   facility_name
# 1   AB5FF571 Apalachee Correctional Institution
# 2   85E1DCF9 Avon Park Correctional Institution
# 3   694B0A6E Baker Correctional Institution
# 4   4043040E Bay Correctional Facility
# 5   763CEDCA Blackwater River Correctional Facility
# 6   A8401B83 Calhoun Correctional Institution
# 7   37904D9E Century Correctional Institution
# 8   CB9EABA3 Central Florida Reception Center prison
# 9   C1102FBD Charlotte Correctional Institution
# 10  38E4B078 Columbia Correctional Institution
# 11  39FC4616 Cross City Correctional Institution
# 12  74E15D35 Dade Correctional Institution
# 13  713A851C Desoto Annex prison
# 14  C666F452 Everglades Correctional Institution
# 15  AE7EF219 Florida State Prison
# 16  5929C8B6 Florida Women's Reception Center prison
# 17  2D4DDBB9 Franklin Correctional Institution
# 18  CB65BA05 Gadsden Correctional Facility
# 19  1C4BF33F Gadsden Re-Entry Center prison
# 20  C22CC7BE Graceville Correctional Facility
# ...

# %%
data_florida <- data %>%
    filter(facility_state == "Florida")

# %%
dim(data_florida)
# Out:
# [1] 179  16

# %%
data_florida %>%
    slice_head(n = 5)
# Out:
#   nyt_id   facility_name                          facility_type facility_city
# 1 AB5FF571 Apalachee Correctional Institution     State prison  Sneads
# 2 85E1DCF9 Avon Park Correctional Institution     State prison  Avon Park
# 3 694B0A6E Baker Correctional Institution         State prison  Sanderson
# 4 4043040E Bay Correctional Facility              State prison  Panama City
# 5 763CEDCA Blackwater River Correctional Facility State prison  Milton
#   facility_county facility_county_fips facility_state facility_lng facility_lat
# 1 Jackson         12063                Florida        -84.88590    30.71231
# 2 Polk            12105                Florida        -81.35965    27.66216
# 3 Baker           12003                Florida        -82.37440    30.21448
# 4 Bay             12005                Florida        -85.50555    30.26668
# 5 Santa Rosa      12113                Florida        -86.95300    30.64565
# ...

# %%
data_florida %>%
    group_by(facility_type) %>%
    tally()
# Out:
#   facility_type            n
# 1 Detention center          6
# 2 Federal halfway house    10
# 3 Federal prison            5
# 4 Jail                     31
# 5 State facility            1
# 6 State juvenile detention 70
# 7 State prison             56

# %%
data_florida %>%
    filter(facility_type == "State juvenile detention") %>%
    slice_head()
# Out:
#   nyt_id   facility_name                              facility_type
# 1 2A540CF1 Broward Regional Juvenile Detention Center State juvenile detention
#   facility_city   facility_county facility_county_fips facility_state
# 1 Fort Lauderdale Broward         12011                Florida
#   facility_lng facility_lat latest_inmate_population max_inmate_population_2020
# 1 -80.17101    26.1242      44                       NA
#   total_inmate_cases total_inmate_deaths total_officer_cases
# 1 7                  0                   33
#   total_officer_deaths note
# 1 0                    NA

# %%
data_florida %>%
    filter(facility_type == "State juvenile detention") %>%
    slice_head(n = 4)
# Out:
#   nyt_id   facility_name
# 1 2A540CF1 Broward Regional Juvenile Detention Center
# 2 22B952FA Palm Beach Regional Juvenile Detention Center
# 3 E3303E7A Miami-Dade Regional Juvenile Detention Center
# 4 2F0B08EB Collier Regional Juvenile Detention Center
#   facility_type            facility_city   facility_county facility_county_fips
# 1 State juvenile detention Fort Lauderdale Broward         12011
# 2 State juvenile detention West Palm Beach Palm Beach      12099
# 3 State juvenile detention Miami           Miami-Dade      12086
# 4 State juvenile detention Naples          Collier         12021
#   facility_state facility_lng facility_lat latest_inmate_population
# 1 Florida        -80.17101    26.12420     44
# 2 Florida        -80.06764    26.75110     25
# 3 Florida        -80.24122    25.80622     43
# 4 Florida        -81.76419    26.13023     28
#   max_inmate_population_2020 total_inmate_cases total_inmate_deaths
# 1 NA                          7                 0
# ...

# %%
data %>%
    filter(facility_state == "Florida", facility_type == "State juvenile detention") %>%
    arrange(desc(latest_inmate_population)) %>%
    slice_max(order_by = latest_inmate_population)
# Out:
#   nyt_id   facility_name              facility_type            facility_city
# 1 D3142189 Saint John's Youth Academy State juvenile detention St. Augustine
#   facility_county facility_county_fips facility_state facility_lng facility_lat
# 1 St. Johns       12109                Florida        -81.33947    29.94228
#   latest_inmate_population max_inmate_population_2020 total_inmate_cases
# 1 55                       NA                         26
#   total_inmate_deaths total_officer_cases total_officer_deaths note
# 1 0                   4                   0                    NA

# %%
data %>%
    filter(facility_state == "Florida", facility_type == "State juvenile detention") %>%
    slice_max(order_by = latest_inmate_population)
# Out:
#   nyt_id   facility_name              facility_type            facility_city
# 1 D3142189 Saint John's Youth Academy State juvenile detention St. Augustine
#   facility_county facility_county_fips facility_state facility_lng facility_lat
# 1 St. Johns       12109                Florida        -81.33947    29.94228
#   latest_inmate_population max_inmate_population_2020 total_inmate_cases
# 1 55                       NA                         26
#   total_inmate_deaths total_officer_cases total_officer_deaths note
# 1 0                   4                   0                    NA

# %%
data %>%
    slice_max(order_by = latest_inmate_population)
# Out:
#   nyt_id   facility_name      facility_type facility_city facility_county
# 1 B3321655 Harris County jail Jail          Houston       Harris
#   facility_county_fips facility_state facility_lng facility_lat
# 1 48201                Texas          -95.35622    29.76343
#   latest_inmate_population max_inmate_population_2020 total_inmate_cases
# 1 8616                     NA                         2609
#   total_inmate_deaths total_officer_cases total_officer_deaths note
# 1 6                   1196                2                    NA

# %%
data %>%
    filter(facility_type == "State prison") %>% 
    slice_min(order_by = latest_inmate_population)
# Out:
#   nyt_id   facility_name                 facility_type facility_city
# 1 DE89E81A Pascagoula Restitution Center State prison  Pascagoula
#   facility_county facility_county_fips facility_state facility_lng facility_lat
# 1 Jackson         28059                Mississippi    -88.54572    30.37176
#   latest_inmate_population max_inmate_population_2020 total_inmate_cases
# 1 4                        NA                         0
#   total_inmate_deaths total_officer_cases total_officer_deaths note
# 1 0                   0                   0                    NA

# %%
data %>%
    filter(facility_type == "State prison") %>%
    slice_max(order_by = latest_inmate_population)
# Out:
#   nyt_id   facility_name                facility_type facility_city
# 1 8175973D Louisiana State Penitentiary State prison  Angola
#   facility_county facility_county_fips facility_state facility_lng facility_lat
# 1 West Feliciana  22125                Louisiana      -91.56899    30.94136
#   latest_inmate_population max_inmate_population_2020 total_inmate_cases
# 1 5433                     5628                       599
#   total_inmate_deaths total_officer_cases total_officer_deaths note
# 1 18                  278                 4                    NA

# %%
data %>%
    distinct(facility_type)
# Out:
#    facility_type
# 1  Low-security work release
# 2  State rehabilitation center
# 3  State prison
# 4  State facility
# 5  State juvenile detention
# 6  State work camp
# 7  State halfway house
# 8  Federal prison
# 9  Detention center
# 10 Jail
# 11 Juvenile detention at jail
# 12 U.S. Marshalls
# 13 Reservation jail
# 14 Federal halfway house

# %%
data %>%
    slice_max(order_by = latest_inmate_population)
# Out:
#   nyt_id   facility_name      facility_type facility_city facility_county
# 1 B3321655 Harris County jail Jail          Houston       Harris
#   facility_county_fips facility_state facility_lng facility_lat
# 1 48201                Texas          -95.35622    29.76343
#   latest_inmate_population max_inmate_population_2020 total_inmate_cases
# 1 8616                     NA                         2609
#   total_inmate_deaths total_officer_cases total_officer_deaths note
# 1 6                   1196                2                    NA

# %%
data %>%
    slice_head(n = 3)
# Out:
#   nyt_id   facility_name
# 1 F3EFE858 Alex City Work Release prison
# 2 5B910220 Alabama Therapeutic Education Facility prison
# 3 02FB1675 Bibb Correctional Facility
#   facility_type               facility_city facility_county
# 1 Low-security work release   Alex City     Coosa
# 2 State rehabilitation center Columbiana    Shelby
# 3 State prison                Brent         Bibb
#   facility_county_fips facility_state facility_lng facility_lat
# 1 01037                Alabama        -86.00901    32.90451
# 2 01117                Alabama        -86.62407    33.18075
# 3 01007                Alabama        -87.16278    32.92075
#   latest_inmate_population max_inmate_population_2020 total_inmate_cases
# 1  188                       NA                        77
# 2  272                       NA                        11
# 3 1725                     1825                       164
#   total_inmate_deaths total_officer_cases total_officer_deaths note
# ...
