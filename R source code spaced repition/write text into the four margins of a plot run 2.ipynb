# %%
plot(1:10, type = "n", ann = FALSE)
mtext("Top", side = 3,  font = 1, col = "red", cex = 3)
mtext("Left", side = 2, font = 2)
mtext("Right", side = 4)
mtext("Bottom", side = 1)
# Out:
# plot without title
